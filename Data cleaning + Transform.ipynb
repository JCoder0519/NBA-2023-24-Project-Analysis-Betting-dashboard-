# %%
import pandas as pd

# Specify the file path
file_path = 'datasets/regular season/Player game logs.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame headers
df.columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2',
#        'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK',
#        'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK',
#        'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK',
#        'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK',
#        'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK',
#        'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK',
#        'WNBA_FANTASY_PTS_RANK', 'AVAILABLE_FLAG', 'PlayerID', 'PlayerName'],
#       dtype='object')

# %%
df = df.loc[:, :'PLUS_MINUS']
df.columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS'],
#       dtype='object')

# %%
# To calculate the efficiency of each game, we need to sum the points, rebounds, assists, steals, and blocks of a player, and then subtract the missed field goals, missed free throws, and turnovers.
df['Efficiency'] = (df['PTS'] + df['REB'] + df['AST'] + df['STL'] + df['BLK']) - (df['FGA'] - df['FGM']) - (df['FTA'] - df['FTM']) - df['TOV']

# %%
# Specify the file path
file_path = 'nba_game_matchups_2023_2024(include playyoffs).csv'

# Read the CSV file into a DataFrame
matchup_df = pd.read_csv(file_path)

matchup_df.info()

matchup_df.drop_duplicates(subset='GAME_ID', inplace=True)

matchup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3704 entries, 0 to 3703
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GAME_ID         3704 non-null   int64
#  1   HOME_TEAM_NAME  3704 non-null   object
#  2   AWAY_TEAM_NAME  3704 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 86.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1852 entries, 0 to 3700
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GAME_ID         1852 non-null   int64
#  1   HOME_TEAM_NAME  1852 non-null   object
#  2   AWAY_TEAM_NAME  1852 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 57.9+ KB

# %%
df.head()
# Out:
#   SEASON_YEAR  PLAYER_ID       PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 1     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 2     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 3     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 4     2023-24    1630173  Precious Achiuwa  Precious  1610612752
#
#   TEAM_ABBREVIATION        TEAM_NAME   GAME_ID            GAME_DATE  \
# 0               NYK  New York Knicks  22301190  2024-04-14T00:00:00
# 1               NYK  New York Knicks  22301175  2024-04-12T00:00:00
# 2               NYK  New York Knicks  22301167  2024-04-11T00:00:00
# 3               NYK  New York Knicks  22301139  2024-04-07T00:00:00
# 4               NYK  New York Knicks  22301119  2024-04-05T00:00:00
#
#        MATCHUP  ... AST  TOV  STL  BLK  BLKA  PF  PFD  PTS  PLUS_MINUS  \
# 0  NYK vs. CHI  ...   2    2    0    1     0   3    0    4          -2
# 1  NYK vs. BKN  ...   0    0    0    0     0   0    0    5           3
# 2    NYK @ BOS  ...   0    1    0    1     2   0    0    2          -9
# 3    NYK @ MIL  ...   0    0    0    0     0   1    0    0           5
# 4    NYK @ CHI  ...   1    1    1    0     1   4    0    0          -2
#
#    Efficiency
# 0           9
# 1           8
# 2           2
# 3          -1
# 4           3
#
# [5 rows x 34 columns]

# %%
import numpy as np

# Left join the two DataFrames on the GAME_ID column
merged_df = df.merge(matchup_df, on='GAME_ID', how='left')
merged_df.head()

merged_df['LOCATION'] = np.where(merged_df['HOME_TEAM_NAME'] == merged_df['TEAM_ABBREVIATION'], 'HOME', 'AWAY')
merged_df.head()
# Out:
#   SEASON_YEAR  PLAYER_ID       PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 1     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 2     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 3     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 4     2023-24    1630173  Precious Achiuwa  Precious  1610612752
#
#   TEAM_ABBREVIATION        TEAM_NAME   GAME_ID            GAME_DATE  \
# 0               NYK  New York Knicks  22301190  2024-04-14T00:00:00
# 1               NYK  New York Knicks  22301175  2024-04-12T00:00:00
# 2               NYK  New York Knicks  22301167  2024-04-11T00:00:00
# 3               NYK  New York Knicks  22301139  2024-04-07T00:00:00
# 4               NYK  New York Knicks  22301119  2024-04-05T00:00:00
#
#        MATCHUP  ... BLK  BLKA  PF  PFD  PTS  PLUS_MINUS  Efficiency  \
# 0  NYK vs. CHI  ...   1     0   3    0    4          -2           9
# 1  NYK vs. BKN  ...   0     0   0    0    5           3           8
# 2    NYK @ BOS  ...   1     2   0    0    2          -9           2
# 3    NYK @ MIL  ...   0     0   1    0    0           5          -1
# 4    NYK @ CHI  ...   0     1   4    0    0          -2           3
#
#    HOME_TEAM_NAME  AWAY_TEAM_NAME  LOCATION
# 0             CHI             NYK      AWAY
# 1             NYK             BKN      HOME
# 2             NYK             BOS      HOME
# 3             NYK             MIL      HOME
# 4             NYK             CHI      HOME
#
# [5 rows x 37 columns]

# %%
# Check for missing values
merged_df.sample(10)
# Out:
#       SEASON_YEAR  PLAYER_ID       PLAYER_NAME NICKNAME     TEAM_ID  \
# 838       2023-24    1630175      Cole Anthony     Cole  1610612753
# 1964      2023-24    1630699  MarJon Beauchamp   MarJon  1610612749
# 24060     2023-24    1629731         Dean Wade     Dean  1610612739
# 26292     2023-24     203469       Cody Zeller     Cody  1610612740
# 17673     2023-24    1626220     Royce O'Neale    Royce  1610612756
# 12226     2023-24     203999      Nikola Jokic   Nikola  1610612743
# 25901     2023-24    1629627   Zion Williamson     Zion  1610612740
# 5424      2023-24     201939     Stephen Curry  Stephen  1610612744
# 18038     2023-24    1630647    Eugene Omoruyi   Eugene  1610612764
# 3630      2023-24    1628973     Jalen Brunson    Jalen  1610612752
#
#       TEAM_ABBREVIATION              TEAM_NAME   GAME_ID            GAME_DATE  \
# 838                 ORL          Orlando Magic  22300172  2023-11-09T00:00:00
# 1964                MIL        Milwaukee Bucks  22300840  2024-02-27T00:00:00
# 24060               CLE    Cleveland Cavaliers  22300191  2023-11-13T00:00:00
# 26292               NOP   New Orleans Pelicans  22301157  2024-04-09T00:00:00
# 17673               PHX           Phoenix Suns  22300796  2024-02-22T00:00:00
# 12226               DEN         Denver Nuggets  22300855  2024-02-29T00:00:00
# 25901               NOP   New Orleans Pelicans  22300525  2024-01-10T00:00:00
# 5424                GSW  Golden State Warriors  22300727  2024-02-07T00:00:00
# 18038               WAS     Washington Wizards  22301137  2024-04-07T00:00:00
# 3630                NYK        New York Knicks  22301201  2023-12-05T00:00:00
#
#            MATCHUP  ... BLK  BLKA  PF  PFD  PTS  PLUS_MINUS  Efficiency  \
# 838    ORL vs. ATL  ...   0     0   3    3    7          -3           1
# 1964   MIL vs. CHA  ...   0     0   0    0    7          -8          11
# 24060    CLE @ SAC  ...   0     0   1    0    0         -18           0
# 26292    NOP @ POR  ...   0     0   1    0    0         -10           1
# 17673    PHX @ DAL  ...   0     1   3    0   10          -7          13
# 12226  DEN vs. MIA  ...   2     0   4    5   18          12          26
# 25901    NOP @ GSW  ...   0     3   2    4   19          23          22
# 5424     GSW @ PHI  ...   1     1   2    3    9          13           5
# 18038    WAS @ TOR  ...   0     1   1    4    4         -14           3
# 3630     NYK @ MIL  ...   0     0   1    8   24         -14          16
#
#        HOME_TEAM_NAME  AWAY_TEAM_NAME  LOCATION
# 838               ATL             ORL      AWAY
# 1964              MIL             CHA      HOME
# 24060             SAC             CLE      AWAY
# 26292             POR             NOP      AWAY
# 17673             PHX             DAL      HOME
# 12226             MIA             DEN      AWAY
# 25901             NOP             GSW      HOME
# 5424              GSW             PHI      HOME
# 18038             TOR             WAS      AWAY
# 3630              NYK             MIL      HOME
#
# [10 rows x 37 columns]

# %%
logo_df = pd.read_csv('datasets/nba_team_logos.csv')
player_headshot_df = pd.read_csv('datasets/nba_players_headshots_2023_2024.csv')

merged_df.head()

merged_df = merged_df.merge(logo_df, on='TEAM_NAME', how='left')

# Rename the column to match the column in the player_headshot_df DataFrame
player_headshot_df.rename(columns={'PERSON_ID': 'PLAYER_ID'}, inplace=True)

merged_df = merged_df.merge(player_headshot_df, on='PLAYER_ID', how='left')
merged_df.columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID_x',
#        'TEAM_ABBREVIATION_x', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'Efficiency',
#        'HOME_TEAM_NAME', 'AWAY_TEAM_NAME', 'LOCATION', 'GP', 'W', 'L',
#        'Logo_URL', 'DISPLAY_FIRST_LAST', 'TEAM_ID_y', 'TEAM_ABBREVIATION_y',
#        'HEADSHOT_URL'],
#       dtype='object')

# %%
merged_df.head()
# Out:
#   SEASON_YEAR  PLAYER_ID       PLAYER_NAME  NICKNAME   TEAM_ID_x  \
# 0     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 1     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 2     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 3     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 4     2023-24    1630173  Precious Achiuwa  Precious  1610612752
#
#   TEAM_ABBREVIATION_x        TEAM_NAME   GAME_ID            GAME_DATE  \
# 0                 NYK  New York Knicks  22301190  2024-04-14T00:00:00
# 1                 NYK  New York Knicks  22301175  2024-04-12T00:00:00
# 2                 NYK  New York Knicks  22301167  2024-04-11T00:00:00
# 3                 NYK  New York Knicks  22301139  2024-04-07T00:00:00
# 4                 NYK  New York Knicks  22301119  2024-04-05T00:00:00
#
#        MATCHUP  ... AWAY_TEAM_NAME  LOCATION  GP   W   L  \
# 0  NYK vs. CHI  ...            NYK      AWAY  82  50  32
# 1  NYK vs. BKN  ...            BKN      HOME  82  50  32
# 2    NYK @ BOS  ...            BOS      HOME  82  50  32
# 3    NYK @ MIL  ...            MIL      HOME  82  50  32
# 4    NYK @ CHI  ...            CHI      HOME  82  50  32
#
#                                             Logo_URL  DISPLAY_FIRST_LAST  \
# 0  https://loodibee.com/wp-content/uploads/nba-ne...    Precious Achiuwa
# 1  https://loodibee.com/wp-content/uploads/nba-ne...    Precious Achiuwa
# 2  https://loodibee.com/wp-content/uploads/nba-ne...    Precious Achiuwa
# 3  https://loodibee.com/wp-content/uploads/nba-ne...    Precious Achiuwa
# 4  https://loodibee.com/wp-content/uploads/nba-ne...    Precious Achiuwa
#
#     TEAM_ID_y  TEAM_ABBREVIATION_y  \
# 0  1610612752                  NYK
# 1  1610612752                  NYK
# 2  1610612752                  NYK
# 3  1610612752                  NYK
# 4  1610612752                  NYK
#
#                                         HEADSHOT_URL
# 0  https://cdn.nba.com/headshots/nba/latest/1040x...
# 1  https://cdn.nba.com/headshots/nba/latest/1040x...
# 2  https://cdn.nba.com/headshots/nba/latest/1040x...
# 3  https://cdn.nba.com/headshots/nba/latest/1040x...
# 4  https://cdn.nba.com/headshots/nba/latest/1040x...
#
# [5 rows x 45 columns]

# %%
average_data = pd.DataFrame(merged_df)


# List of columns to calculate the mean for
columns_to_average = ['MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
                      'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
                      'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'Efficiency']

# Create a dictionary for aggregation
agg_dict = {col: 'mean' for col in columns_to_average}

# Group by PLAYER_NAME, TEAM_NAME, and LOCATION and calculate the mean for the specified columns
average_stats = average_data.groupby(['PLAYER_NAME', 'PLAYER_ID','TEAM_NAME', 'LOCATION']).agg(agg_dict).reset_index()

# Calculate overall averages without grouping by location
overall_stats = average_data.groupby(['PLAYER_NAME', 'PLAYER_ID','TEAM_NAME']).agg(agg_dict).reset_index()
overall_stats['LOCATION'] = 'OVERALL'

# Concatenate the two DataFrames
final_stats = pd.concat([average_stats, overall_stats], ignore_index=True)

# Display the resulting DataFrame
final_stats.head()
final_stats = final_stats.round(2)
final_stats
# Out:
#           PLAYER_NAME  PLAYER_ID             TEAM_NAME LOCATION    MIN   FGM  \
# 0            AJ Green    1631260       Milwaukee Bucks     AWAY   9.70  1.41
# 1            AJ Green    1631260       Milwaukee Bucks     HOME  12.15  1.55
# 2          AJ Griffin    1631100         Atlanta Hawks     AWAY   9.13  1.12
# 3          AJ Griffin    1631100         Atlanta Hawks     HOME   8.14  0.75
# 4           AJ Lawson    1630639      Dallas Mavericks     AWAY   9.37  1.32
# ...               ...        ...                   ...      ...    ...   ...
# 1942      Zach LaVine     203897         Chicago Bulls  OVERALL  34.87  6.80
# 1943   Zavier Simpson    1630285     Memphis Grizzlies  OVERALL  23.05  2.43
# 1944       Zeke Nnaji    1630192        Denver Nuggets  OVERALL   9.93  1.19
# 1945  Ziaire Williams    1630533     Memphis Grizzlies  OVERALL  20.35  2.94
# 1946  Zion Williamson    1629627  New Orleans Pelicans  OVERALL  31.53  8.91
#
#         FGA  FG_PCT  FG3M  FG3A  ...   AST   TOV   STL   BLK  BLKA    PF  \
# 0      3.11    0.36  1.19  2.78  ...  0.44  0.19  0.07  0.07  0.07  0.74
# 1      3.86    0.36  1.28  3.24  ...  0.62  0.24  0.24  0.07  0.03  1.00
# 2      3.62    0.26  0.50  2.00  ...  0.12  0.50  0.00  0.12  0.12  0.00
# 3      2.75    0.33  0.50  1.92  ...  0.33  0.33  0.08  0.08  0.17  0.50
# 4      3.16    0.33  0.37  1.37  ...  0.58  0.47  0.37  0.11  0.32  0.58
# ...     ...     ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 1942  15.04    0.43  2.36  6.76  ...  3.92  2.08  0.84  0.32  0.80  2.28
# 1943   7.71    0.28  0.71  2.43  ...  3.57  1.43  1.00  0.43  1.00  1.57
# 1944   2.57    0.39  0.10  0.40  ...  0.55  0.47  0.26  0.66  0.40  1.40
# 1945   7.41    0.34  1.14  3.71  ...  1.47  1.29  0.71  0.18  0.53  1.67
# 1946  15.63    0.57  0.09  0.26  ...  5.03  2.76  1.09  0.67  1.73  2.27
#
#        PFD    PTS  PLUS_MINUS  Efficiency
# 0     0.30   4.11        0.22        3.96
# 1     0.41   4.86        1.52        4.31
# 2     0.00   2.75       -4.75        0.75
# 3     0.08   2.17       -1.08        1.33
# 4     0.47   3.63        0.74        3.53
# ...    ...    ...         ...         ...
# 1942  2.80  19.48       -3.68       18.80
# 1943  0.43   6.00       -4.14        7.00
# 1944  1.33   3.21       -2.90        4.64
# 1945  1.45   8.24       -4.84        8.10
# 1946  5.17  22.87        2.04       23.89
#
# [1947 rows x 27 columns]

# %%
df = pd.DataFrame(final_stats)

# Separate the dataset into HOME and AWAY
home_df = df[df['LOCATION'] == 'HOME'].groupby(['PLAYER_NAME', 'TEAM_NAME']).agg({'Efficiency': 'mean'}).reset_index()
home_df['LOCATION'] = 'HOME'

away_df = df[df['LOCATION'] == 'AWAY'].groupby(['PLAYER_NAME', 'TEAM_NAME']).agg({'Efficiency': 'mean'}).reset_index()
away_df['LOCATION'] = 'AWAY'

# Merge home and away dataframes on PLAYER_NAME and TEAM_NAME
merged_df = pd.merge(home_df, away_df, on=['PLAYER_NAME', 'TEAM_NAME'], suffixes=('_HOME', '_AWAY'))

# Calculate the difference in Efficiency between home and away
merged_df['Efficiency_DIFF'] = (merged_df['Efficiency_HOME'] - merged_df['Efficiency_AWAY']).abs()

merged_df = merged_df.sort_values(by='Efficiency_DIFF', ascending=False)

# Top 20 players with the highest difference in Efficiency between home and away games
merged_df.head(20)
# Out:
#             PLAYER_NAME               TEAM_NAME  Efficiency_HOME  \
# 451      Mouhamed Gueye           Atlanta Hawks            -1.00
# 465       Nicolas Batum             LA Clippers             2.50
# 291     Jeff Dowtin Jr.      Philadelphia 76ers            16.00
# 602    Tristan Vukcevic      Washington Wizards             2.00
# 571          Taze Moore  Portland Trail Blazers             1.67
# 549        Shake Milton         Detroit Pistons            17.00
# 161       Dexter Dennis        Dallas Mavericks            -2.00
# 421      Marques Bolden       Charlotte Hornets            12.00
# 509      Quentin Grimes         Detroit Pistons            -1.00
# 177       Dylan Windler           Atlanta Hawks             4.40
# 187       Evan Fournier         New York Knicks             4.50
# 425         Mason Jones        Sacramento Kings            -1.00
# 565          Taj Gibson         Detroit Pistons             9.50
# 339   Justin Champagnie      Washington Wizards             4.71
# 28      Anfernee Simons  Portland Trail Blazers            16.80
# 41   Bennedict Mathurin          Indiana Pacers            16.11
# 411      Mamadi Diakite       San Antonio Spurs             9.00
# 283       Javonte Green           Chicago Bulls            15.83
# 547      Shaedon Sharpe  Portland Trail Blazers            11.61
# 236           Ja Morant       Memphis Grizzlies            23.20
#
#     LOCATION_HOME  Efficiency_AWAY LOCATION_AWAY  Efficiency_DIFF
# 451          HOME            15.00          AWAY            16.00
# 465          HOME            16.00          AWAY            13.50
# 291          HOME             2.62          AWAY            13.38
# 602          HOME            14.17          AWAY            12.17
# 571          HOME            13.00          AWAY            11.33
# 549          HOME             6.00          AWAY            11.00
# 161          HOME             8.00          AWAY            10.00
# 421          HOME             2.75          AWAY             9.25
# 509          HOME             7.00          AWAY             8.00
# 177          HOME            12.00          AWAY             7.60
# 187          HOME            -3.00          AWAY             7.50
# 425          HOME             6.00          AWAY             7.00
# 565          HOME             3.00          AWAY             6.50
# 339          HOME            11.00          AWAY             6.29
# 28           HOME            22.94          AWAY             6.14
# 41           HOME             9.97          AWAY             6.14
# 411          HOME             3.00          AWAY             6.00
# 283          HOME            21.67          AWAY             5.84
# 547          HOME            17.43          AWAY             5.82
# 236          HOME            29.00          AWAY             5.80

# %%
final_stats['Season Type'] = 'Regular Season'

playoff_data = pd.read_csv('average_stats_playoffs.csv')

playoff_data['Season Type'] = 'Playoffs'

# Concatenate the regular season and playoff DataFrames
final_data = pd.concat([final_stats, playoff_data], ignore_index=True)

# %%
logo_df = pd.read_csv('datasets/nba_team_logos.csv')
player_headshot_df = pd.read_csv('datasets/nba_players_headshots_2023_2024.csv')

# Merge the final_data DataFrame with the logo_df DataFrame on TEAM_NAME
final_data = pd.merge(final_data, logo_df, on='TEAM_NAME')

# Merge the final_data DataFrame with the player_headshot_df DataFrame on PLAYER_ID
final_data = pd.merge(final_data, player_headshot_df, on='PLAYER_ID')

final_data.columns
# Out:
# Index(['PLAYER_NAME', 'PLAYER_ID', 'TEAM_NAME', 'LOCATION', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD',
#        'PTS', 'PLUS_MINUS', 'Efficiency', 'Season Type', 'GP', 'W', 'L',
#        'Logo_URL', 'DISPLAY_FIRST_LAST', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'HEADSHOT_URL'],
#       dtype='object')

# %%
final_data['PLAYER_ID'] = final_data['PLAYER_ID'].astype(int)

position_df = pd.read_csv('active_nba_players_with_positions.csv')

# merge the position_df DataFrame with the final_data DataFrame
final_data = final_data.merge(position_df, on='PLAYER_ID', how='left')

# %%
regular_def = pd.read_csv('datasets/regular season/team_defense_stats_2023_2024.csv')
playoff_def = pd.read_csv('datasets/playoff/Playoff_team_defense_stats_2023_2024.csv')

# %%
playoff_def['Season Type'] = 'Playoffs'
regular_def['Season Type'] = 'Regular Season'

# %%
concatenated_data_def = pd.concat([regular_def, playoff_def], ignore_index=True)
concatenated_data_def.sample(10)
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT     MIN  DEF_RATING  \
# 31  1610612739     Cleveland Cavaliers  12   5   7  0.417   576.0       111.1
# 26  1610612759       San Antonio Spurs  82  22  60  0.268  3966.0       115.6
# 0   1610612737           Atlanta Hawks  82  36  46  0.439  3971.0       118.4
# 40  1610612740    New Orleans Pelicans   4   0   4  0.000   192.0       109.6
# 24  1610612757  Portland Trail Blazers  82  21  61  0.256  3976.0       116.6
# 38  1610612749         Milwaukee Bucks   6   2   4  0.333   293.0       119.4
# 39  1610612750  Minnesota Timberwolves  16   9   7  0.563   768.0       110.9
# 11  1610612754          Indiana Pacers  82  47  35  0.573  3941.0       117.6
# 3   1610612766       Charlotte Hornets  82  21  61  0.256  3946.0       119.2
# 27  1610612761         Toronto Raptors  82  25  57  0.305  3961.0       118.1
#
#     DREB  DREB_PCT  ...  DEF_RATING_RANK  DREB_RANK  DREB_PCT_RANK  STL_RANK  \
# 31   373     0.699  ...                8          7              9         5
# 26  2778     0.721  ...               21          8             13        22
# 0   2639     0.717  ...               27         22             16        16
# 40   133     0.797  ...                4         15              1        11
# 24  2469     0.697  ...               23         30             28        12
# 38   199     0.697  ...               14         10             10        13
# 39   509     0.762  ...                7          4              3         3
# 11  2578     0.700  ...               24         28             26        11
# 3   2538     0.709  ...               29         29             22        25
# 27  2607     0.694  ...               26         26             29        10
#
#     BLK_RANK  OPP_PTS_OFF_TOV_RANK  OPP_PTS_2ND_CHANCE_RANK  OPP_PTS_FB_RANK  \
# 31         7                    10                       11               10
# 26         3                    27                       23               17
# 0         26                    18                       12               28
# 40        14                     3                        1                3
# 24        27                    28                       22               29
# 38        12                     2                        6                3
# 39         4                    14                       10               13
# 11         8                    12                       26               11
# 3         25                    20                       21               12
# 27        19                    23                       29               18
#
#     OPP_PTS_PAINT_RANK     Season Type
# 31                  10        Playoffs
# 26                  28  Regular Season
# 0                   25  Regular Season
# 40                   1        Playoffs
# 24                  24  Regular Season
# 38                   6        Playoffs
# 39                  13        Playoffs
# 11                  30  Regular Season
# 3                   23  Regular Season
# 27                  26  Regular Season
#
# [10 rows x 31 columns]

# %%
final_data = pd.merge(final_data, concatenated_data_def, on=['TEAM_ID', 'Season Type'])

# %%
playoff_all_shot = pd.read_csv('datasets/playoff/All shots.csv')
regular_all_shot = pd.read_csv('datasets/regular season/all_players_shot_data_2023_2024.csv')

playoff_all_shot['Season Type'] = 'Playoffs'
regular_all_shot['Season Type'] = 'Regular Season'

# %%
# Concatenate the regular season and playoff DataFrames
all_shot_data = pd.concat([regular_all_shot, playoff_all_shot], ignore_index=True)
all_shot_data.sample(10)

matchup_data = pd.read_csv('nba_game_matchups_2023_2024(include playyoffs).csv')

# Merge the all_shot_data DataFrame with the matchup_data DataFrame

# Drop duplicates in the GAME_ID column
matchup_df.drop_duplicates(subset='GAME_ID', inplace=True)


all_shot_data = pd.merge(all_shot_data, matchup_df, on='GAME_ID')


all_shot_data['LOCATION'] = np.where(all_shot_data['HOME_TEAM_NAME'] == all_shot_data['HTM'], 'HOME', 'AWAY')
all_shot_data.loc[0:3]

all_shot_data.to_csv('all_shot_data_final.csv', index=False)

# %%
all_shot_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232541 entries, 0 to 232540
# Data columns (total 29 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   GRID_TYPE            232541 non-null  object
#  1   GAME_ID              232541 non-null  int64
#  2   GAME_EVENT_ID        232541 non-null  int64
#  3   PLAYER_ID            232541 non-null  int64
#  4   PLAYER_NAME          232541 non-null  object
#  5   TEAM_ID              232541 non-null  int64
#  6   TEAM_NAME            232541 non-null  object
#  7   PERIOD               232541 non-null  int64
#  8   MINUTES_REMAINING    232541 non-null  int64
#  9   SECONDS_REMAINING    232541 non-null  int64
#  10  EVENT_TYPE           232541 non-null  object
#  11  ACTION_TYPE          232541 non-null  object
#  12  SHOT_TYPE            232541 non-null  object
#  13  SHOT_ZONE_BASIC      232541 non-null  object
#  14  SHOT_ZONE_AREA       232541 non-null  object
#  15  SHOT_ZONE_RANGE      232541 non-null  object
#  16  SHOT_DISTANCE        232541 non-null  int64
#  17  LOC_X                232541 non-null  int64
#  18  LOC_Y                232541 non-null  int64
#  19  SHOT_ATTEMPTED_FLAG  232541 non-null  int64
#  20  SHOT_MADE_FLAG       232541 non-null  int64
#  21  GAME_DATE            232541 non-null  int64
#  22  HTM                  232541 non-null  object
#  23  VTM                  232541 non-null  object
#  24  player_name          232541 non-null  object
#  25  Season Type          232541 non-null  object
#  26  HOME_TEAM_NAME       232541 non-null  object
#  27  AWAY_TEAM_NAME       232541 non-null  object
#  28  LOCATION             232541 non-null  object
# dtypes: int64(13), object(16)
# memory usage: 51.5+ MB

# %%
# Define the list of Eastern Conference teams
east_teams = ["Atlanta Hawks", "Boston Celtics", "Brooklyn Nets", "Charlotte Hornets", "Chicago Bulls",
              "Cleveland Cavaliers", "Detroit Pistons", "Indiana Pacers", "Miami Heat", "Milwaukee Bucks",
              "New York Knicks", "Orlando Magic", "Philadelphia 76ers", "Toronto Raptors", "Washington Wizards"]

# Add the Conference column
final_data["Conference"] = final_data["TEAM_NAME_x"].apply(lambda x: "East" if x in east_teams else "West")

# Display the updated DataFrame
final_data.columns
# Out:
# Index(['PLAYER_NAME', 'PLAYER_ID', 'TEAM_NAME_x', 'LOCATION', 'MIN_x', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB_x', 'REB', 'AST', 'TOV', 'STL_x', 'BLK_x', 'BLKA', 'PF',
#        'PFD', 'PTS', 'PLUS_MINUS', 'Efficiency', 'Season Type', 'GP_x', 'W_x',
#        'L_x', 'Logo_URL', 'DISPLAY_FIRST_LAST_x', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'HEADSHOT_URL', 'DISPLAY_FIRST_LAST_y', 'POSITION',
#        'TEAM_NAME_y', 'GP_y', 'W_y', 'L_y', 'W_PCT', 'MIN_y', 'DEF_RATING',
#        'DREB_y', 'DREB_PCT', 'STL_y', 'BLK_y', 'OPP_PTS_OFF_TOV',
#        'OPP_PTS_2ND_CHANCE', 'OPP_PTS_FB', 'OPP_PTS_PAINT', 'GP_RANK',
#        'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'DEF_RATING_RANK',
#        'DREB_RANK', 'DREB_PCT_RANK', 'STL_RANK', 'BLK_RANK',
#        'OPP_PTS_OFF_TOV_RANK', 'OPP_PTS_2ND_CHANCE_RANK', 'OPP_PTS_FB_RANK',
#        'OPP_PTS_PAINT_RANK', 'Conference'],
#       dtype='object')

# %%
final_data.to_csv('final_data.csv', index=False)

# %%
all_shot_data.columns
# Out:
# Index(['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
#        'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
#        'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE',
#        'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE',
#        'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE',
#        'HTM', 'VTM', 'player_name', 'Season Type', 'HOME_TEAM_NAME',
#        'AWAY_TEAM_NAME', 'LOCATION'],
#       dtype='object')

# %%
len(all_shot_data[all_shot_data['TEAM_NAME'] == 'Los Angeles Lakers'])
# Out:
# 7600

# %%
final_data[final_data['OPP_PTS_PAINT'] > 50]
# Out:
#              PLAYER_NAME  PLAYER_ID             TEAM_NAME_x LOCATION  MIN_x  \
# 0               AJ Green    1631260         Milwaukee Bucks     AWAY   9.70
# 1               AJ Green    1631260         Milwaukee Bucks     HOME  12.15
# 2             AJ Griffin    1631100           Atlanta Hawks     AWAY   9.13
# 3             AJ Griffin    1631100           Atlanta Hawks     HOME   8.14
# 4              AJ Lawson    1630639        Dallas Mavericks     AWAY   9.37
# ...                  ...        ...                     ...      ...    ...
# 2413        Tyrese Maxey    1630178      Philadelphia 76ers  OVERALL  44.58
# 2414  Wendell Carter Jr.    1628976           Orlando Magic  OVERALL  26.43
# 2415   Wendell Moore Jr.    1631111  Minnesota Timberwolves  OVERALL   3.08
# 2416      Xavier Tillman    1630214          Boston Celtics  OVERALL   8.64
# 2417          Zeke Nnaji    1630192          Denver Nuggets  OVERALL   4.66
#
#         FGM    FGA  FG_PCT  FG3M  FG3A  ...  DEF_RATING_RANK  DREB_RANK  \
# 0      1.41   3.11    0.36  1.19  2.78  ...               19          3
# 1      1.55   3.86    0.36  1.28  3.24  ...               19          3
# 2      1.12   3.62    0.26  0.50  2.00  ...               27         22
# 3      0.75   2.75    0.33  0.50  1.92  ...               27         22
# 4      1.32   3.16    0.33  0.37  1.37  ...               18         14
# ...     ...    ...     ...   ...   ...  ...              ...        ...
# 2413  11.00  23.00    0.47  3.67  9.17  ...               11         12
# 2414   2.71   6.71    0.39  1.00  3.57  ...                1          9
# 2415   0.50   1.17    0.28  0.17  0.67  ...                7          4
# 2416   0.62   1.00    0.56  0.12  0.12  ...                3          2
# 2417   0.67   1.00    0.67  0.00  0.00  ...                6          5
#
#       DREB_PCT_RANK  STL_RANK  BLK_RANK  OPP_PTS_OFF_TOV_RANK  \
# 0                 4        26        15                     6
# 1                 4        26        15                     6
# 2                16        16        26                    18
# 3                16        16        26                    18
# 4                21        24        17                     7
# ...             ...       ...       ...                   ...
# 2413             15        12         9                     5
# 2414              4         9        10                     7
# 2415              3         3         4                    14
# 2416              2         2         2                    15
# 2417              5         7         8                    11
#
#       OPP_PTS_2ND_CHANCE_RANK  OPP_PTS_FB_RANK  OPP_PTS_PAINT_RANK  Conference
# 0                          12               10                  19        East
# 1                          12               10                  19        East
# 2                          12               28                  25        East
# 3                          12               28                  25        East
# 4                          24               26                  20        West
# ...                       ...              ...                 ...         ...
# 2413                        8                7                   4        East
# 2414                        3                8                   8        East
# 2415                       10               13                  13        West
# 2416                       14               14                  15        East
# 2417                        9               12                  11        West
#
# [2418 rows x 68 columns]

# %%
playoff_df = pd.read_csv('datasets/playoff/playoffs player game_logs.csv')

# %%
regular_df = pd.read_csv('datasets/regular season/Player game logs.csv')

# %%
playoff_df.columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2',
#        'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK',
#        'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK',
#        'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK',
#        'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK',
#        'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK',
#        'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK',
#        'WNBA_FANTASY_PTS_RANK', 'AVAILABLE_FLAG', 'PlayerID', 'PlayerName'],
#       dtype='object')

# %%
regular_df.head()
# Out:
#   SEASON_YEAR  PLAYER_ID       PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 1     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 2     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 3     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 4     2023-24    1630173  Precious Achiuwa  Precious  1610612752
#
#   TEAM_ABBREVIATION        TEAM_NAME   GAME_ID            GAME_DATE  \
# 0               NYK  New York Knicks  22301190  2024-04-14T00:00:00
# 1               NYK  New York Knicks  22301175  2024-04-12T00:00:00
# 2               NYK  New York Knicks  22301167  2024-04-11T00:00:00
# 3               NYK  New York Knicks  22301139  2024-04-07T00:00:00
# 4               NYK  New York Knicks  22301119  2024-04-05T00:00:00
#
#        MATCHUP  ... PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  \
# 0  NYK vs. CHI  ...       45        49               37                    55
# 1  NYK vs. BKN  ...       45        45               26                    63
# 2    NYK @ BOS  ...       45        58               55                    61
# 3    NYK @ MIL  ...       45        67               20                    74
# 4    NYK @ CHI  ...       45        67               37                    64
#
#    DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK  AVAILABLE_FLAG  PlayerID  \
# 0        10         1                     53               1   1630173
# 1        10         1                     61               1   1630173
# 2        10         1                     61               1   1630173
# 3        10         1                     74               1   1630173
# 4        10         1                     64               1   1630173
#
#          PlayerName
# 0  Precious Achiuwa
# 1  Precious Achiuwa
# 2  Precious Achiuwa
# 3  Precious Achiuwa
# 4  Precious Achiuwa
#
# [5 rows x 70 columns]

# %%
# Dropping specified columns from the dataframe
columns_to_drop = ['PLUS_MINUS', 'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 
                   'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 
                   'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 
                   'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 
                   'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 
                   'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 
                   'NBA_FANTASY_PTS_RANK', 'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK', 
                   'AVAILABLE_FLAG']

regular_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
playoff_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# %%
regular_df['Season Type'] = 'Regular Season'

playoff_df['Season Type'] = 'Playoffs'

all_gamelog_df = pd.concat([regular_df, playoff_df], ignore_index=True)

# %%
all_gamelog_df[all_gamelog_df['Season Type'] == 'Playoffs']
# Out:
#       SEASON_YEAR  PLAYER_ID       PLAYER_NAME  NICKNAME     TEAM_ID  \
# 26401     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 26402     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 26403     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 26404     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 26405     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# ...           ...        ...               ...       ...         ...
# 28081     2023-24    1627826       Ivica Zubac     Ivica  1610612746
# 28082     2023-24    1627826       Ivica Zubac     Ivica  1610612746
# 28083     2023-24    1627826       Ivica Zubac     Ivica  1610612746
# 28084     2023-24    1627826       Ivica Zubac     Ivica  1610612746
# 28085     2023-24    1627826       Ivica Zubac     Ivica  1610612746
#
#       TEAM_ABBREVIATION        TEAM_NAME   GAME_ID            GAME_DATE  \
# 26401               NYK  New York Knicks  42300217  2024-05-19T00:00:00
# 26402               NYK  New York Knicks  42300216  2024-05-17T00:00:00
# 26403               NYK  New York Knicks  42300215  2024-05-14T00:00:00
# 26404               NYK  New York Knicks  42300214  2024-05-12T00:00:00
# 26405               NYK  New York Knicks  42300213  2024-05-10T00:00:00
# ...                 ...              ...       ...                  ...
# 28081               LAC      LA Clippers  42300175  2024-05-01T00:00:00
# 28082               LAC      LA Clippers  42300174  2024-04-28T00:00:00
# 28083               LAC      LA Clippers  42300173  2024-04-26T00:00:00
# 28084               LAC      LA Clippers  42300172  2024-04-23T00:00:00
# 28085               LAC      LA Clippers  42300171  2024-04-21T00:00:00
#
#            MATCHUP  ... TOV  STL  BLK  BLKA  PF  PFD  PTS  PlayerID  \
# 26401  NYK vs. IND  ...   0    0    0     1   3    2    4   1630173
# 26402    NYK @ IND  ...   0    2    2     2   3    5   12   1630173
# 26403  NYK vs. IND  ...   0    2    2     0   4    1    4   1630173
# 26404    NYK @ IND  ...   0    0    0     1   0    1    8   1630173
# 26405    NYK @ IND  ...   2    0    3     1   2    1    5   1630173
# ...            ...  ...  ..  ...  ...   ...  ..  ...  ...       ...
# 28081  LAC vs. DAL  ...   1    1    0     0   4    2   15   1627826
# 28082    LAC @ DAL  ...   1    1    1     1   4    2   13   1627826
# 28083    LAC @ DAL  ...   2    1    1     2   4    4   19   1627826
# 28084  LAC vs. DAL  ...   2    1    0     1   2    5   13   1627826
# 28085  LAC vs. DAL  ...   1    1    1     1   2    4   20   1627826
#
#              PlayerName  Season Type
# 26401  Precious Achiuwa     Playoffs
# 26402  Precious Achiuwa     Playoffs
# 26403  Precious Achiuwa     Playoffs
# 26404  Precious Achiuwa     Playoffs
# 26405  Precious Achiuwa     Playoffs
# ...                 ...          ...
# 28081       Ivica Zubac     Playoffs
# 28082       Ivica Zubac     Playoffs
# 28083       Ivica Zubac     Playoffs
# 28084       Ivica Zubac     Playoffs
# 28085       Ivica Zubac     Playoffs
#
# [1685 rows x 35 columns]

# %%
log1_df = pd.read_csv('nba_player_game_logs_active_players_2021_22_playoff.csv')
log11_df = pd.read_csv('nba_player_game_logs_active_players_2021_22.csv')

log2_df = pd.read_csv('nba_player_game_logs_active_players_2022_23_playoff.csv')
log22_df = pd.read_csv('nba_player_game_logs_active_players_2022_23.csv')

log11_df['Season Type'] = 'Regular Season'
log22_df['Season Type'] = 'Regular Season'

log2_df['Season Type'] = 'Playoffs'
log1_df['Season Type'] = 'Playoffs'

log2_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
log1_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
log11_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
log22_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# %%
all_gamelog_2021_2024_df = pd.concat([all_gamelog_df, log1_df, log11_df, log22_df, log2_df], ignore_index=True)

all_gamelog_2021_2024_df.head()

all_gamelog_2021_2024_df.to_csv('player_gamelog_2021_2024.csv', index=False)

# %%
all_gamelog_2021_2024_df.columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'PTS', 'PlayerID', 'PlayerName', 'Season Type',
#        'Season'],
#       dtype='object')

# %%
match_df1 = pd.read_csv('nba_game_matchups_2021_2022.csv')
match_df2 = pd.read_csv('nba_game_matchups_2021_2022_playoff.csv')
match_df3 = pd.read_csv('nba_game_matchups_2022_2023.csv')
match_df4 = pd.read_csv('nba_game_matchups_2022_2023_playoff.csv')
match_df5 = pd.read_csv('nba_game_matchups_2023_2024(include playyoffs).csv')

all_matchup = pd.concat([match_df1, match_df2, match_df3, match_df4, match_df5], ignore_index=True)

all_matchup.drop_duplicates(subset='GAME_ID', inplace=True)

# %%
all_matchup.head()
# Out:
#     GAME_ID HOME_TEAM_NAME AWAY_TEAM_NAME
# 0  22101223            MEM            BOS
# 1  22101226            TOR            NYK
# 2  22101230            POR            UTA
# 3  22101219            DAL            SAS
# 4  22101217            CHA            WAS

# %%
all_gamelog_2021_2024_df = all_gamelog_2021_2024_df.merge(all_matchup, on='GAME_ID', how='left')

all_gamelog_2021_2024_df.head()
# Out:
#   SEASON_YEAR  PLAYER_ID       PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 1     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 2     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 3     2023-24    1630173  Precious Achiuwa  Precious  1610612752
# 4     2023-24    1630173  Precious Achiuwa  Precious  1610612752
#
#   TEAM_ABBREVIATION        TEAM_NAME   GAME_ID            GAME_DATE  \
# 0               NYK  New York Knicks  22301190  2024-04-14T00:00:00
# 1               NYK  New York Knicks  22301175  2024-04-12T00:00:00
# 2               NYK  New York Knicks  22301167  2024-04-11T00:00:00
# 3               NYK  New York Knicks  22301139  2024-04-07T00:00:00
# 4               NYK  New York Knicks  22301119  2024-04-05T00:00:00
#
#        MATCHUP  ... BLKA  PF  PFD  PTS  PlayerID        PlayerName  \
# 0  NYK vs. CHI  ...    0   3    0    4   1630173  Precious Achiuwa
# 1  NYK vs. BKN  ...    0   0    0    5   1630173  Precious Achiuwa
# 2    NYK @ BOS  ...    2   0    0    2   1630173  Precious Achiuwa
# 3    NYK @ MIL  ...    0   1    0    0   1630173  Precious Achiuwa
# 4    NYK @ CHI  ...    1   4    0    0   1630173  Precious Achiuwa
#
#       Season Type  Season  HOME_TEAM_NAME  AWAY_TEAM_NAME
# 0  Regular Season     NaN             CHI             NYK
# 1  Regular Season     NaN             NYK             BKN
# 2  Regular Season     NaN             NYK             BOS
# 3  Regular Season     NaN             NYK             MIL
# 4  Regular Season     NaN             NYK             CHI
#
# [5 rows x 38 columns]

# %%
all_gamelog_2021_2024_df['Opponent Team'] = np.where(all_gamelog_2021_2024_df['HOME_TEAM_NAME'] == all_gamelog_2021_2024_df['TEAM_ABBREVIATION'], all_gamelog_2021_2024_df['AWAY_TEAM_NAME'], all_gamelog_2021_2024_df['HOME_TEAM_NAME'])

# %%
all_gamelog_2021_2024_df.sample(10)
# Out:
#       SEASON_YEAR  PLAYER_ID              PLAYER_NAME  NICKNAME     TEAM_ID  \
# 21435     2023-24    1641767             Ben Sheppard       Ben  1610612754
# 56173     2022-23    1630217             Desmond Bane   Desmond  1610612763
# 16118     2023-24    1629003             Shake Milton     Shake  1610612765
# 40773     2021-22    1629659      Talen Horton-Tucker     Talen  1610612747
# 41902     2021-22    1630552            Jalen Johnson     Jalen  1610612737
# 81234     2022-23     202083          Wesley Matthews    Wesley  1610612749
# 50072     2021-22     203082            Terrence Ross  Terrence  1610612753
# 38916     2021-22     201145               Jeff Green      Jeff  1610612743
# 62633     2022-23    1628983  Shai Gilgeous-Alexander      Shai  1610612760
# 48215     2021-22     203486            Mason Plumlee     Mason  1610612766
#
#       TEAM_ABBREVIATION              TEAM_NAME   GAME_ID            GAME_DATE  \
# 21435               IND         Indiana Pacers  22300039  2023-11-21T00:00:00
# 56173               MEM      Memphis Grizzlies  22201052  2023-03-17T00:00:00
# 16118               DET        Detroit Pistons  22300776  2024-02-13T00:00:00
# 40773               LAL     Los Angeles Lakers  22100365  2021-12-07T00:00:00
# 41902               ATL          Atlanta Hawks  22100202  2021-11-15T00:00:00
# 81234               MIL        Milwaukee Bucks  42200101  2023-04-16T00:00:00
# 50072               ORL          Orlando Magic  22100071  2021-10-29T00:00:00
# 38916               DEN         Denver Nuggets  22100500  2021-12-26T00:00:00
# 62633               OKC  Oklahoma City Thunder  22200611  2023-01-10T00:00:00
# 48215               CHA      Charlotte Hornets  22101001  2022-03-11T00:00:00
#
#            MATCHUP  ... PF  PFD  PTS  PlayerID               PlayerName  \
# 21435    IND @ ATL  ...  0    0    5   1641767             Ben Sheppard
# 56173    MEM @ SAS  ...  5    2   21   1630217             Desmond Bane
# 16118    DET @ LAL  ...  1    0    8   1629003             Shake Milton
# 40773  LAL vs. BOS  ...  3    2   12   1629659      Talen Horton-Tucker
# 41902  ATL vs. ORL  ...  0    0    0   1630552            Jalen Johnson
# 81234  MIL vs. MIA  ...  2    1    6    202083          Wesley Matthews
# 50072    ORL @ TOR  ...  2    2    9    203082            Terrence Ross
# 38916    DEN @ LAC  ...  1    1    4    201145               Jeff Green
# 62633    OKC @ MIA  ...  2    6   26   1628983  Shai Gilgeous-Alexander
# 48215    CHA @ NOP  ...  4    1    9    203486            Mason Plumlee
#
#           Season Type   Season  HOME_TEAM_NAME  AWAY_TEAM_NAME  Opponent Team
# 21435  Regular Season      NaN             IND             ATL            ATL
# 56173  Regular Season  2022-23             MEM             SAS            SAS
# 16118  Regular Season      NaN             LAL             DET            LAL
# 40773  Regular Season  2021-22             LAL             BOS            BOS
# 41902  Regular Season  2021-22             ATL             ORL            ORL
# 81234        Playoffs  2022-23             MIA             MIL            MIA
# 50072  Regular Season  2021-22             ORL             TOR            TOR
# 38916  Regular Season  2021-22             LAC             DEN            LAC
# 62633  Regular Season  2022-23             MIA             OKC            MIA
# 48215  Regular Season  2021-22             CHA             NOP            NOP
#
# [10 rows x 39 columns]

# %%
all_gamelog_2021_2024_df.to_csv('player_gamelog_2021_2024.csv', index=False)

# %%
all_gamelog_2021_2024_df.iloc[0]
# Out:
# SEASON_YEAR                      2023-24
# PLAYER_ID                        1630173
# PLAYER_NAME             Precious Achiuwa
# NICKNAME                        Precious
# TEAM_ID                       1610612752
# TEAM_ABBREVIATION                    NYK
# TEAM_NAME                New York Knicks
# GAME_ID                         22301190
# GAME_DATE            2024-04-14T00:00:00
# MATCHUP                      NYK vs. CHI
# WL                                     W
# MIN                            18.506667
# FGM                                    2
# FGA                                    3
# FG_PCT                             0.667
# FG3M                                   0
# FG3A                                   0
# FG3_PCT                              0.0
# FTM                                    0
# FTA                                    0
# FT_PCT                               0.0
# OREB                                   1
# DREB                                   4
# REB                                    5
# AST                                    2
# TOV                                    2
# STL                                    0
# BLK                                    1
# BLKA                                   0
# PF                                     3
# PFD                                    0
# PTS                                    4
# PlayerID                         1630173
# PlayerName              Precious Achiuwa
# Season Type               Regular Season
# Season                               NaN
# HOME_TEAM_NAME                       CHI
# AWAY_TEAM_NAME                       NYK
# Opponent Team                        CHI
# Name: 0, dtype: object

# %%
all_gamelog_2021_2024_df['Double_Double_rebound'] = all_gamelog_2021_2024_df.apply(lambda row: 1 if row['PTS'] >= 10 and row['REB'] >= 10 else 0, axis=1)
all_gamelog_2021_2024_df['Double_Double_assist'] = all_gamelog_2021_2024_df.apply(lambda row: 1 if row['PTS'] >= 10 and row['AST'] >= 10 else 0, axis=1)

# %%
all_gamelog_2021_2024_df['Double_Double_rebound'].value_counts()
# Out:
# Double_Double_rebound
# 0    76381
# 1     5603
# Name: count, dtype: int64

# %%
all_gamelog_2021_2024_df['Double_Double_assist'].value_counts()
# Out:
# Double_Double_assist
# 0    80183
# 1     1801
# Name: count, dtype: int64
